# %%
import pandas as pd

# %%
df = pd.read_csv("performance.csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["capital"])

# %%
df = pd.read_csv("perform_41024.csv")
plt.plot(df["capital"])

# %%
df = pd.read_csv("data/perform_41124.csv")

# %%
plt.plot(df["capital"])

# %%
import pandas as pd 
df = pd.read_csv("data/perform_41224.csv")

# %%
import matplotlib.pyplot as plt
plt.plot(df["capital"])

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("26APR24.csv")

# %%
plt.plot(df["capital"])

# %%
dft = pd.read_csv("22APR24trades.csv")
